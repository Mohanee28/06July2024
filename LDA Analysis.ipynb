# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohanee28/06July2024/blob/main/LDA%20Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/nba_final.csv')

# %%
df.head()
# Out:
#     Rk         Player.x  Player_ID Pos1 Pos2  Age   Tm   G  GS    MP  ...  \
# 0  170     A.J. Hammons  hammoaj01    C  NaN   24  DAL  22   0   7.4  ...
# 1   58     Aaron Brooks  brookaa01   PG  NaN   32  IND  65   0  13.8  ...
# 2  157     Aaron Gordon  gordoaa01   SF  NaN   21  ORL  80  72  28.7  ...
# 3  352    Adreian Payne  paynead01   PF  NaN   25  MIN  18   0   7.5  ...
# 4   10  Al-Farouq Aminu  aminual01   PF  NaN   26  POR  61  25  29.1  ...
#
#    Conference   Role   Fvot  FRank  Pvot  PRank  Mvot  MRank  Score  Play
# 0        West  Front    786    123   NaN    NaN   NaN    NaN   83.5    No
# 1         Est   Back   2474     64   NaN    NaN   NaN    NaN   48.2    No
# 2         Est  Front  22774     29   NaN    NaN   NaN    NaN   40.0    No
# 3        West  Front    861    120   1.0   52.0   NaN    NaN   75.5    No
# 4        West  Front   4971     69   7.0   23.0   NaN    NaN   42.8    No
#
# [5 rows x 45 columns]

# %%
df.columns
# Out:
# Index(['Rk', 'Player.x', 'Player_ID', 'Pos1', 'Pos2', 'Age', 'Tm', 'G', 'GS',
#        'MP', 'FG', 'FGA', 'FG.', 'X3P', 'X3PA', 'X3P.', 'X2P', 'X2PA', 'X2P.',
#        'eFG.', 'FT', 'FTA', 'FT.', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK',
#        'TOV', 'PF', 'PTS', 'Salary', 'mean_views', 'Season', 'Conference',
#        'Role', 'Fvot', 'FRank', 'Pvot', 'PRank', 'Mvot', 'MRank', 'Score',
#        'Play'],
#       dtype='object')

# %%
df.shape
# Out:
# (1408, 45)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1408 entries, 0 to 1407
# Data columns (total 45 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rk          1408 non-null   int64
#  1   Player.x    1408 non-null   object
#  2   Player_ID   1408 non-null   object
#  3   Pos1        1408 non-null   object
#  4   Pos2        12 non-null     object
#  5   Age         1408 non-null   int64
#  6   Tm          1408 non-null   object
#  7   G           1408 non-null   int64
#  8   GS          1408 non-null   int64
#  9   MP          1408 non-null   float64
#  10  FG          1408 non-null   float64
#  11  FGA         1408 non-null   float64
#  12  FG.         1404 non-null   float64
#  13  X3P         1408 non-null   float64
#  14  X3PA        1408 non-null   float64
#  15  X3P.        1309 non-null   float64
#  16  X2P         1408 non-null   float64
#  17  X2PA        1408 non-null   float64
#  18  X2P.        1393 non-null   float64
# ...

# %%
df.notnull().sum()
# Out:
# Rk            1408
# Player.x      1408
# Player_ID     1408
# Pos1          1408
# Pos2            12
# Age           1408
# Tm            1408
# G             1408
# GS            1408
# MP            1408
# FG            1408
# FGA           1408
# FG.           1404
# X3P           1408
# X3PA          1408
# X3P.          1309
# X2P           1408
# X2PA          1408
# X2P.          1393
# eFG.          1404
# FT            1408
# FTA           1408
# FT.           1361
# ORB           1408
# DRB           1408
# TRB           1408
# AST           1408
# STL           1408
# BLK           1408
# TOV           1408
# PF            1408
# PTS           1408
# Salary        1346
# mean_views    1270
# Season        1408
# Conference    1408
# Role          1408
# Fvot          1408
# FRank         1408
# Pvot          1249
# PRank         1249
# Mvot          1004
# MRank         1004
# Score         1408
# Play          1408
# dtype: int64

# %%
df.notna().sum()
# Out:
# Rk            1408
# Player.x      1408
# Player_ID     1408
# Pos1          1408
# Pos2            12
# Age           1408
# Tm            1408
# G             1408
# GS            1408
# MP            1408
# FG            1408
# FGA           1408
# FG.           1404
# X3P           1408
# X3PA          1408
# X3P.          1309
# X2P           1408
# X2PA          1408
# X2P.          1393
# eFG.          1404
# FT            1408
# FTA           1408
# FT.           1361
# ORB           1408
# DRB           1408
# TRB           1408
# AST           1408
# STL           1408
# BLK           1408
# TOV           1408
# PF            1408
# PTS           1408
# Salary        1346
# mean_views    1270
# Season        1408
# Conference    1408
# Role          1408
# Fvot          1408
# FRank         1408
# Pvot          1249
# PRank         1249
# Mvot          1004
# MRank         1004
# Score         1408
# Play          1408
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Rk               0
# Player.x         0
# Player_ID        0
# Pos1             0
# Pos2          1396
# Age              0
# Tm               0
# G                0
# GS               0
# MP               0
# FG               0
# FGA              0
# FG.              4
# X3P              0
# X3PA             0
# X3P.            99
# X2P              0
# X2PA             0
# X2P.            15
# eFG.             4
# FT               0
# FTA              0
# FT.             47
# ORB              0
# DRB              0
# TRB              0
# AST              0
# STL              0
# BLK              0
# TOV              0
# PF               0
# PTS              0
# Salary          62
# mean_views     138
# Season           0
# Conference       0
# Role             0
# Fvot             0
# FRank            0
# Pvot           159
# PRank          159
# Mvot           404
# MRank          404
# Score            0
# Play             0
# dtype: int64

# %%
df['Pos2'] = df['Pos2'].replace(np.nan, 'NONE')
df['Pos2'].unique()
# Out:
# array(['NONE', 'C', 'SG', 'SF', 'PF'], dtype=object)

# %%
df['Pos2'].value_counts()
# Out:
# Pos2
# NONE    1396
# SG         5
# SF         3
# C          2
# PF         2
# Name: count, dtype: int64

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# Rk            0
# Player.x      0
# Player_ID     0
# Pos1          0
# Pos2          0
# Age           0
# Tm            0
# G             0
# GS            0
# MP            0
# FG            0
# FGA           0
# FG.           0
# X3P           0
# X3PA          0
# X3P.          0
# X2P           0
# X2PA          0
# X2P.          0
# eFG.          0
# FT            0
# FTA           0
# FT.           0
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# Salary        0
# mean_views    0
# Season        0
# Conference    0
# Role          0
# Fvot          0
# FRank         0
# Pvot          0
# PRank         0
# Mvot          0
# MRank         0
# Score         0
# Play          0
# dtype: int64

# %%
# !pip install sweetviz

# %%
if not hasattr(np, 'VisibleDeprecationWarning'):
    np.VisibleDeprecationWarning = type('VisibleDeprecationWarning', (DeprecationWarning,), {})

# %%
import sweetviz as sv
report = sv.analyze(df)
report.show_html('Report.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df = df.drop(['Player.x', 'Player_ID'], axis=1)

# %%
df.shape
# Out:
# (1408, 43)

# %%
df.describe()
# Out:
#                 Rk          Age            G           GS           MP  \
# count  1408.000000  1408.000000  1408.000000  1408.000000  1408.000000
# mean    257.701705    26.139205    54.099432    25.906960    20.162713
# std     150.765855     4.282550    24.052508    28.664578     9.066041
# min       1.000000    19.000000     1.000000     0.000000     0.700000
# 25%     127.000000    23.000000    36.000000     1.000000    13.300000
# 50%     257.000000    25.000000    62.000000    13.000000    20.000000
# 75%     385.250000    29.000000    74.000000    52.000000    27.500000
# max     540.000000    42.000000    82.000000    82.000000    37.800000
#
#                 FG          FGA          FG.          X3P         X3PA  ...  \
# count  1408.000000  1408.000000  1408.000000  1408.000000  1408.000000  ...
# mean      3.262429     7.173153     0.446332     0.856250     2.420810  ...
# std       2.181694     4.591826     0.094679     0.792307     2.061737  ...
# ...

# %%
df.describe(include='O')
# Out:
#         Pos1  Pos2    Tm   Season Conference   Role  Play
# count   1408  1408  1408     1408       1408   1408  1408
# unique     5     5    30        3          2      2     2
# top       SG  NONE   MIL  2017-18       West  Front    No
# freq     324  1396    51      498        704    779  1335

# %%
obj_col = ['Pos1', 'Pos2', 'Tm', 'Season', 'Conference', 'Role', 'Play']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Le = LabelEncoder()

# %%
for i in obj_col:
  df[i] = Le.fit_transform(df[i])
print(obj_col)
# Out:
# ['Pos1', 'Pos2', 'Tm', 'Season', 'Conference', 'Role', 'Play']

# %%
df.head()
# Out:
#     Rk  Pos1  Pos2  Age  Tm   G  GS    MP   FG   FGA  ...  Conference  Role  \
# 0  170     0     1   24   6  22   0   7.4  0.8   1.9  ...           1     1
# 1   58     2     1   32  11  65   0  13.8  1.9   4.6  ...           0     0
# 2  157     3     1   21  21  80  72  28.7  4.9  10.8  ...           0     1
# 3  352     1     1   25  17  18   0   7.5  1.3   3.0  ...           1     1
# 4   10     1     1   26  24  61  25  29.1  3.0   7.6  ...           1     1
#
#     Fvot  FRank  Pvot  PRank  Mvot  MRank  Score  Play
# 0    786    123   0.0    0.0   0.0    0.0   83.5     0
# 1   2474     64   0.0    0.0   0.0    0.0   48.2     0
# 2  22774     29   0.0    0.0   0.0    0.0   40.0     0
# 3    861    120   1.0   52.0   0.0    0.0   75.5     0
# 4   4971     69   7.0   23.0   0.0    0.0   42.8     0
#
# [5 rows x 43 columns]

# %%
##def encode_cat_col (dataframe, columns):
  ##data_frame = dataframe.copy()
  ##le=LabelEncoder()
  ##for col in columns:
    ##data_frame[col] = le.fit_transform(data_frame[col].astype(str))
  ##return data_frame

# %%
##df = encode_cat_col(df, obj_col)

# %%
x = df.drop(['Play'], axis = 1)
y = df['Play']

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x = sc.fit_transform(x)

# %%
print(x)
# Out:
# [[-0.58191469 -1.40108842 -0.07184075 ... -0.16623906 -1.46817686
#    0.19138945]
#  [-1.32505241 -0.01428174 -0.07184075 ... -0.16623906 -1.46817686
#   -0.66146791]
#  [-0.66817174  0.67912159 -0.07184075 ... -0.16623906 -1.46817686
#   -0.85958209]
#  ...
#  [ 0.33373715  1.37252493 -0.07184075 ... -0.16623906  0.83574403
#    1.36799438]
#  [ 0.8977256  -1.40108842 -0.07184075 ... -0.16623906  0.54775392
#   -0.13960618]
#  [ 1.32237572  1.37252493 -0.07184075 ... -0.16623906  0.83574403
#    1.09256735]]

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
LDA = LinearDiscriminantAnalysis(n_components=1)

# %%
X = LDA.fit_transform(x,y)

# %%
X.shape
# Out:
# (1408, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 30)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (1126, 42)
# (282, 42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg = LogisticRegression()

# %%
lg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lg_prid = lg.predict(x_test)

# %%
from sklearn.metrics import *

# %%
accuracy_scor = accuracy_score(lg_prid, y_test)

# %%
print(accuracy_scor)
# Out:
# 0.9893617021276596

# %%
print('r2_score:', round(r2_score(lg_prid,y_test),4))
# Out:
# r2_score: 0.7581

# %%
print('MSE:', round(mean_squared_error(lg_prid, y_test), 4))
# Out:
# MSE: 0.0106

# %%
print('MOE:', round(mean_absolute_error(lg_prid, y_test), 4))
# Out:
# MOE: 0.0106

# %%
# !pip install pycaret

# %%
from pycaret.class import *
