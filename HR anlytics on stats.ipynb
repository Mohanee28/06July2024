# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"D:\His\Intellipaat\Machine Learning\Stats model - HR Analytics\People Charm_data.xlsx", sheet_name = "Data")
df[:5]
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
# 4               0.41            0.50                 2              153
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium
# 2                  4             0     1                      0  sales  medium
# 3                  3             0     1                      0  sales     low
# 4                  3             0     1                      0  sales     low

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.rename(columns = {"timeSpent.company": "timeSpent_company"}, inplace = True)

# %%
df.head()
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
# 4               0.41            0.50                 2              153
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium
# 2                  4             0     1                      0  sales  medium
# 3                  3             0     1                      0  sales     low
# 4                  3             0     1                      0  sales     low

# %%
df.keys()
# Out:
# Index(['satisfactoryLevel', 'lastEvaluation', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent_company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.sum()
# Out:
# satisfactoryLevel                                                  9191.89
# lastEvaluation                                                    10740.81
# numberOfProjects                                                     57042
# avgMonthlyHours                                                    3015554
# timeSpent_company                                                    52470
# workAccident                                                          2169
# left                                                                  3571
# promotionInLast5years                                                  319
# dept                     salessalessalessalessalessalessalessalessaless...
# salary                   lowmediummediumlowlowlowlowlowlowlowlowlowlowl...
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 3008

# %%
df = df.drop_duplicates(keep = "first")

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent_company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
##check normality

# %%
df.describe()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# count       11991.000000    11991.000000      11991.000000     11991.000000
# mean            0.629658        0.716683          3.802852       200.473522
# std             0.241070        0.168343          1.163238        48.727813
# min             0.090000        0.360000          2.000000        96.000000
# 25%             0.480000        0.570000          3.000000       157.000000
# 50%             0.660000        0.720000          4.000000       200.000000
# 75%             0.820000        0.860000          5.000000       243.000000
# max             1.000000        1.000000          7.000000       310.000000
#
#        timeSpent_company  workAccident          left  promotionInLast5years
# count       11991.000000  11991.000000  11991.000000           11991.000000
# mean            3.364857      0.154282      0.166041               0.016929
# ...

# %%
plt.figure(figsize = (10,4))
plt.hist(df['satisfactoryLevel'])
plt.show()

# %%
from scipy.stats import shapiro

# %%
## Hypothisis
#h0 - data is normaly distributed
#h1 - data is not normaly distributed

# %%
stat, p_value =shapiro (df['satisfactoryLevel'])
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 11991.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
print(p_value)
# Out:
# 6.698511499093979e-52

# %%
round(6.698511499093979e-52)
# Out:
# 0

# %%
print(stat)
# Out:
# 0.9526718376165387

# %%
#p-value is less than 0.05, so reject the null hypothesis and the data is not normaly distributed

# %%
df["salary"].unique()
# Out:
# array([1, 2, 0])

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
df1 = df

# %%
from sklearn.preprocessing import LabelEncoder
L1 = LabelEncoder()
df1 ['salary_LE']= L1.fit_transform(df1['salary'])

# %%
df1
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14992               0.30            0.88                 5              245
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
df1['salary_LE'].unique()
# Out:
# array([1, 2, 0])

# %%
from sklearn.preprocessing import OrdinalEncoder
L2 = OrdinalEncoder(categories = [['low', 'medium', 'high']])
df1 ['salary_Encoder'] = L2.fit_transform(df1[['salary']])

# %%
df1
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
df1['salary_Encoder'].unique()
# Out:
# array([0., 1., 2.])

# %%
df2 = df1.drop(columns = ['dept', 'salary'], axis = 1)
df2
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
df2.corr()
# Out:
#                        satisfactoryLevel  lastEvaluation  numberOfProjects  \
# satisfactoryLevel               1.000000        0.105021         -0.142970
# lastEvaluation                  0.105021        1.000000          0.349333
# numberOfProjects               -0.142970        0.349333          1.000000
# avgMonthlyHours                -0.020048        0.339742          0.417211
# timeSpent.company              -0.100866        0.131591          0.196786
# workAccident                    0.058697       -0.007104         -0.004741
# left                           -0.388375        0.006567          0.023787
# promotionInLast5years           0.025605       -0.008684         -0.006064
# salary_LE                       0.011754        0.013965          0.009672
# salary_Encoder                  0.050022       -0.013002         -0.001803
#
#                        avgMonthlyHours  timeSpent.company  workAccident  \
# ...

# %%
plt.figure(figsize = (10,4))
sns.heatmap(df2.corr(), annot = True, cmap = "coolwarm")
# Out:
# <Axes: >

# %%
emp = df[(df['satisfactoryLevel'] >= 0) & (df['satisfactoryLevel'] <= 0.50) & (df['timeSpent.company'] == 2) & (df['avgMonthlyHours'] > 130) & (df['avgMonthlyHours'] < 200)]

# %%
emp.head()
# Out:
#       satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 35                 0.13            0.78                 6              152
# 379                0.48            0.78                 2              198
# 413                0.34            0.67                 4              141
# 1239               0.14            0.47                 4              175
# 1426               0.19            0.58                 5              182
#
#       timeSpent.company  workAccident  left  promotionInLast5years       dept  \
# 35                    2             0     1                      0    support
# 379                   2             0     1                      0  technical
# 413                   2             0     1                      0      sales
# 1239                  2             0     1                      0      RandD
# 1426                  2             0     0                      0  technical
#
#       salary  salary_LE  salary_Encoder
# ...

# %%
emp['left'].value_counts()
# Out:
# left
# 0    233
# 1     14
# Name: count, dtype: int64

# %%
emp.shape
# Out:
# (247, 12)

# %%
emp['avgMonthlyHours'].mean()
# Out:
# 166.98785425101215
